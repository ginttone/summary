# %% [markdown]
# <a href="https://colab.research.google.com/github/ginttone/summary/blob/master/test_word_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# %%
import matplotlib.font_manager as fm
sys_font = fm.findSystemFonts()
[f for f in sys_font if 'Nanum' in f]

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

path = '/usr/share/fonts/truetype/nanum/NanumBrush.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family = font_name)
fm._rebuild()
# Out:
# Nanum Brush Script

# %%
import matplotlib.pyplot as plt
plt.title('안녕')
# Out:
# Text(0.5, 1.0, '안녕')

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
plt.title('안녕')
# Out:
# Text(0.5, 1.0, '안녕')

# %%
# !pip install konlpy wordcloud

# %%
import nltk
from konlpy.corpus import kobill
files_ko = kobill.fileids()
doc_ko = kobill.open('1809890.txt').read()

# %%
from konlpy.tag import Okt
t = Okt()
tokens_ko = t.nouns(doc_ko)
tokens_ko

# %%
ko = nltk.Text(tokens_ko, name = 'test')

plt.figure(figsize= (16,8))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud

data = ko.vocab().most_common(200)

path = '/usr/share/fonts/truetype/nanum/NanumBrush.ttf'
wc = WordCloud(font_path = path,
               relative_scaling=0.2,
               background_color='white').generate_from_frequencies(dict(data))

plt.figure()
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# [word_cloud](https://pinkwink.kr/1324)
